# %% [markdown]
# # Classes
# - classes are kind of when we combine something like a dictionary and give it methods/functions
# - what is a class? - a class is a blueprint for an object that contains some data (attributes/fields) and functions(methods)
# -functions and methods are pretty much the same thing. Methods need an object to act on or are part of class.. ie methods are functions that are built into a class (methods are functions that are in a class)
# - method uses . notation with parentheses (ex. aList.sort() is a method)
# - instance -> copy or spawn of a class. Concrete manifestation that is generated by a class. An object is very flexible in that can be made to look a variety of ways.
# - class = blueprint. building house = instance

# %% [markdown]
# # Objects
# - are (often times) supposed to represent some type of concrete thing or real world object (person, dog, animal, etc.)

# %% [markdown]
# # back to classes

# %%
# to create we must first define it like a function
#define syntax -> class classname

class Person:
    #inside this -> attributes/fields
    name = "Cris"
    age = 27

# the classes are like bluebrints. We can use variables within a class to act as a "master copy" that can be copied into outside objects/variables. Everytime we create these copies, we call them instances or instantiating the class

instance1 = Person() #creates instance of Person

#to access attributes or fields in a class we use dot notation (.)
print(instance1.name)
print(instance1.age)

#classes can be instantiated and then modified in order to suit your needs
instance2 = Person()
instance2.name = "Tim"
instance2.age = 45

print(instance2.name)
print(instance2.age)

# %% [markdown]
# # Class vs Instance Variable
# - classes can represent real world objects with data and behavior that can be modified and changed
# - if we want the attribute/data to be blank until we create a class then we can use instance variableds
# - instance varible-> can be set or changed upon the creation of an object/instance
# - class variable-> do not change upon the creation/instantiation of an object BUT can be changed afterwards if needed

# %%
# create a class callled dog. Dog will have a couple of attributes - name and animal. Dog will always have the class variable of animal = "dog", but every dog can have a different name. so we use our instance variable (name) to set the name of the dog upon creation

class Dog:
    #class variable
    animal = "Dog"
    #anytime we create a new dog, it will always have animal = "Dog". If we need to change it later, we can

    #instance variables are used in arguments/parameters when creating an instance in order to set attributes upon creation
    #contructors: initalize the instance variables with some data that the user or other parts of the program provide upon creation. It is null until we give it data
    # constructors are special methods/functions
    # the self keyword is used when creating an instance variable
    #self = that individuals instance value or data (ie internal state)
    #__init__ = constructor keyword in python #init letting us know that the following are instanced variables

    #make a method or function in a class we just use the same syntax we do with a function
    def __init__(self, name, age): # age was added last to show example#self -> its own internal state #after self then we add a comma and put variables and more commas
        #name is going to be whatever you put in the parentheses
        self.name = name
        self.age = age #adding this one second to show how this works

    # common behavior can be created with functions
    def bark(self):
        print("Woof")

        

dog1 = Dog("Cris", 8)
print(dog1.name)
print(dog1.age)
#method call or object function call
dog1.bark()

dog2 = Dog("Spot", 10)
print(dog2.name)
print(dog2.age)
dog2.bark()

#there are class variables and they should be the same
print(dog1.animal)
print(dog2.animal)

#class variables can change afterwards after creating the object
dog2.animal = "Cat"
print(dog2.animal)

#use inputs to set internal state or instance variables
dog_name = input("What is the dogs name: ")
dog_age = int(input("What is the dogs age: "))

dog3 = Dog(dog_name, dog_age)
print(dog3.name)
print(dog3.age)
dog3.bark()

# %% [markdown]
# # Access Modifiers

# %% [markdown]
# - encapsulation --> wrap data and give them the ability to be accessible or inaccessible
# - we can set variables so that other classes and outsdie data cannot interfere or change data unless specified or used with a method
# - useful to limiting bugs
# - we can limit access using functions so only certain groups/people/classes can manipulate data
# - provide better security and robustness

# %%
class Pet:
    def __init__(self, name, animal, age):
        #to make fields/attributes/variables private we use a double underscore aka a 'dunder' (__)
        self.__name = name
        self.__animal = animal
        self.__age = age

    #methods called getters/setters
    #getter retreives data
    #setters change/modify data

    #getters
    def get_name(self):
        return self.__name
    def get_animal(self):
        return self.__animal
    def get_age(self):
        return self.__age
    
    #setters
    def set_name(self, name):
        self.__name = name
    def set_animal(self, animal):
        self.__animal = animal
    def set_age(self, age):
        self.__age = age

pet1 = Pet("Spot", "dog", 5)
#run our getters
print(pet1.get_name())
print(pet1.get_animal())
print(pet1.get_age())

#change pets name, age, and type
pet1.set_name("Jack")
pet1.set_animal("Cat")
pet1.set_age(2)

#display new values
print(pet1.get_name())
print(pet1.get_animal())
print(pet1.get_age())

# %% [markdown]
# # Inheritance YT Video Code

# %%
#inheritnace (you can inherit eyes or nose from parents. the parents pass those traits on to you)
#if grandpa dies and you inherit his land. He gave it to you
# it means getting something from someone else

#what does it mean in cpu programming?

class Parent():
    def print_last_name(self):
        print("Alvarez")

class Child(Parent): # The parenthese means we can take a previous class and their functions and add it into our new one. we just have to put the class name inside of the function
    def print_first_name(self):
        print("Cristian")
    
    def print_last_name(self): #this was added last/ we are overrode the the Parent class so we now have a new last name and the old one wont be in effect anymore. we just need to have the same function name
        print("shnizleberg")

Cristian = Child()
Cristian.print_first_name()
Cristian.print_last_name() #this will work because the child class inehrited the parent class. It will be with the same object

# %% [markdown]
# # inhertance and polymorphism prof lecture
# - non-inheritance polymorphism
# - polymorphism - functinos have the same name but do different things
# - group by behavior

# %%
#non-inheritance poly
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    def move(self):
        print("VROOOOM")

class Boat:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    def move(self):
        print("SAIL")

class Plane:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    def move(self):
        print("FLY")

car1 = Car("Ford", "Mutang")
boat1 = Boat("Ibiza", "Touring 20")
plane1 = Plane("Boeing", "747")

car1.move() #this is polymorpheism because all of the functions have the same name but because its in a different function it means that they do different things
boat1.move()
plane1.move()

# %%
# inhertiance based polymorphism -> Inherit a class and overrides functions or methods

#super or parent class
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    #default behavior
    def move(self):
        print("MOVE")

#inheritance and override the move method/function
class Car(Vehicle): #we're inheriting the Vehicle class so we dont have to repeat it in these classes
    def move(self):
        print("Vroom")

class Plane(Vehicle):
    def move(self): #this functions are getting overridden since our parent class has "MOVE" action in it
        print("FLY")

class Boat(Vehicle):
    def move(self):
        print("SAIL")


car1 = Car("Ford", "Mustang")
plane1 = Plane("Boeing", "747")
boat1 = Boat("Princess", "40M")

car1.move()
plane1.move()
boat1.move()

# %% [markdown]
# # Advanced Functions

# %% [markdown]
# # decorators and methods as functions
# - in python, a decorator is a function that takes another function as input and extends or modifies its behavior without explicitly modifying the original functions code
# - decorators are a powerful way to add functionality to existing functions or classes, promoting code reusablility and seperation of concerns
#
# - a decorator is a "wrapper" for a function that adds code to the function in order to make it do something extra

# %%
def my_decorator(func): #func is a placeholder for the original function which is say_hello. my_decorator is the decarator
    def wrapper(): #the wrapper
        print("Something added before the function")
        func()
        print("Something added after the function")
    return wrapper

@my_decorator #we are calling this function so it will execute as well
def say_hello(): #this is the original function
    print("Hello")

say_hello()


#all of this basicall means say_hello = my_decorator(say_hello)

# %%
# say we want a class..... but that class is just a group of functions
#ie the class is used to organize functions instead of holding data

#I want a class that contains a ton of math utilities to add, multiply, divide, etc. two numbers together

class MyMathUtil:
    #a static method is one that does not require an object or data
    @staticmethod #means we dont need an object for this to get used
    def add(x,y):
        return x + y
    
    @staticmethod
    def multiply(x,y):
        return x * y
    
    @staticmethod
    def divide(x,y):
        return x / y
    
print(MyMathUtil.add(10,34))
print(MyMathUtil.multiply(54,32))
print(MyMathUtil.divide(30,3))

# %% [markdown]
# # Lambda Functions
# - anonymouns or anon functions -> functions without a name used as a tiny function usually inside of another function
# - why? -> main reason is two fold
# 1. you can create variables that are expressions
# 2. very useful in event based programming when an event happens and you can just write a function inside of the () instad of calling a new def function outside

# %%
#example of traditional function to double a number
def double_number(number):
    double = number * 2
    return double

doubled_number = double_number(5)
print(doubled_number)

# %%
#using a lambda function to do the same thing
#lambda function -> we can use an expression (=) to define a functiuon with an anon function. this derives from lambda calc
#anon functions will always return function
# an example of an expression is x = 6
#syntax ->variable name = lambda parameter: parameter body or function body
double = lambda number: number * 2
answer = double(40)
print(answer)

#python treats functions as first class citizens aka functions can take in other functions as param/arguments... which is also known as function chaining
double = lambda number: number * 2
print(double(34))

#multiply lambda example
mutliply = lambda first_num, second_num: first_num * second_num
print(mutliply(5,6))

# %% [markdown]
# # Recursion
# - using a more functional style vs OOP
# - functional - seperate data and functions/methods
# - oop/classes - bundle action and data together
#
# - true functional alnguages (haskell, kind of rsut) have some of the following characterstics:
# 1. they use recursion - dont loop
# 2. no classes -> they may have objects/dicts/structures but no methods
# 3. variables are immutable or constants by default -> they instead are replaced or overwriten (state)
# 4. they can use map and reduce to filter out a list

# %%
# recursion -> fucntion that calls itself over and over until a condition is met. kind of the function version of loop (but not really)

def countdown(number):
    if number <= 0:
        return #a solo return will exit out of a loop (recursion)
    else:
        print(number)
        countdown(number - 1)

countdown(5)
